# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotiarora-cse/Demo-repository/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d9f67f8b-8052-471a-b06e-4d3ad2d334b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9f67f8b-8052-471a-b06e-4d3ad2d334b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(uploaded.keys())
# Out:
# dict_keys(['65k_anime_data.xlsx.xlsx'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("65k_anime_data.xlsx.xlsx")
print(df)
# Out:
#                                   title  \
# 0                          Cowboy Bebop
# 1       Cowboy Bebop: Tengoku no Tobira
# 2                                Trigun
# 3                    Witch Hunter Robin
# 4                        Bouken Ou Beet
# ...                                 ...
# 29148        Ibitte Konai Gibo to Gishi
# 29149               DJ Pikachu Full Set
# 29150                            Wanted
# 29151  Kanojo ga Separate o Matou Riyuu
# 29152  Yuanshen: Song of the night star
#
#                                            title_english  \
# 0                                           Cowboy Bebop
# 1                                Cowboy Bebop: The Movie
# 2                                                 Trigun
# 3                                     Witch Hunter Robin
# 4                                 Beet the Vandel Buster
# ...                                                  ...
# 29148  My Mother-in-Law and Sister-in-Law Who Don't B...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("65k_anime_data.xlsx.xlsx")
print(df)
# Out:
#                                   title  \
# 0                          Cowboy Bebop
# 1       Cowboy Bebop: Tengoku no Tobira
# 2                                Trigun
# 3                    Witch Hunter Robin
# 4                        Bouken Ou Beet
# ...                                 ...
# 29148        Ibitte Konai Gibo to Gishi
# 29149               DJ Pikachu Full Set
# 29150                            Wanted
# 29151  Kanojo ga Separate o Matou Riyuu
# 29152  Yuanshen: Song of the night star
#
#                                            title_english  \
# 0                                           Cowboy Bebop
# 1                                Cowboy Bebop: The Movie
# 2                                                 Trigun
# 3                                     Witch Hunter Robin
# 4                                 Beet the Vandel Buster
# ...                                                  ...
# 29148  My Mother-in-Law and Sister-in-Law Who Don't B...
# ...

# %%
df.loc[4]
# Out:
# title                                                Bouken Ou Beet
# title_english                                Beet the Vandel Buster
# title_japanese                                   å†’é™ºçŽ‹ãƒ“ã‚£ãƒˆ
# image             https://cdn.myanimelist.net/images/anime/7/215...
# aired_from                                2004-09-30 00:00:00+00:00
# aired_to                                  2005-09-29 00:00:00+00:00
# synopsis          It is the dark century and the people are suff...
# status                                              Finished Airing
# episodes                                                         52
# rating                                                PG - Children
# rank                                                         4816.0
# popularity                                                     5680
# members                                                       16325
# favorites                                                        16
# ...

# %%
df.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                                       title_japanese  \
# 0                        ã‚«ã‚¦ãƒœãƒ¼ã‚¤ãƒ“ãƒãƒƒãƒ—
# 1           ã‚«ã‚¦ãƒœãƒ¼ã‚¤ãƒ“ãƒãƒƒãƒ— å¤©å›½ã®æ‰‰
# 2                                    ãƒˆãƒ©ã‚¤ã‚¬ãƒ³
# 3  Witch Hunter ROBIN (ã‚¦ã‚¤ãƒƒãƒãƒãƒ³ã‚¿ãƒ¼ãƒ...
# 4                                 å†’é™ºçŽ‹ãƒ“ã‚£ãƒˆ
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# ...

# %%
unique_groups = df[["title_english", "title_japanese", "rank", "score", "rating","episodes"]].drop_duplicates()
print(unique_groups)
# Out:
#                                            title_english  \
# 0                                           Cowboy Bebop
# 1                                Cowboy Bebop: The Movie
# 2                                                 Trigun
# 3                                     Witch Hunter Robin
# 4                                 Beet the Vandel Buster
# ...                                                  ...
# 29147                                                NaN
# 29148  My Mother-in-Law and Sister-in-Law Who Don't B...
# 29150                                                NaN
# 29151                                                NaN
# 29152             Genshin Impact: Song of the night star
#
#                                           title_japanese     rank  score  \
# 0                            ã‚«ã‚¦ãƒœãƒ¼ã‚¤ãƒ“ãƒãƒƒãƒ—     47.0   8.75
# 1               ã‚«ã‚¦ãƒœãƒ¼ã‚¤ãƒ“ãƒãƒƒãƒ— å¤©å›½ã®æ‰‰    216.0   8.38
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df.isna().sum()
# Out:
# title                 0
# title_english     16678
# title_japanese      222
# image                 0
# aired_from        25030
# aired_to          27046
# synopsis           5183
# status                0
# episodes              0
# rating              686
# rank               6792
# popularity            0
# members               0
# favorites             0
# score             10472
# scored_by         10472
# genres             6174
# themes            11918
# demographics      18365
# dtype: int64

# %%
df.isna().mean().sum()
# Out:
# np.float64(4.769251878022844)

# %%
df.dropna(thresh = 1000)
# Out:
# Empty DataFrame
# Columns: [title, title_english, title_japanese, image, aired_from, aired_to, synopsis, status, episodes, rating, rank, popularity, members, favorites, score, scored_by, genres, themes, demographics]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#                                   title  \
# 0                          Cowboy Bebop
# 1       Cowboy Bebop: Tengoku no Tobira
# 2                                Trigun
# 3                    Witch Hunter Robin
# 4                        Bouken Ou Beet
# ...                                 ...
# 29148        Ibitte Konai Gibo to Gishi
# 29149               DJ Pikachu Full Set
# 29150                            Wanted
# 29151  Kanojo ga Separate o Matou Riyuu
# 29152  Yuanshen: Song of the night star
#
#                                                    image            status  \
# 0      https://cdn.myanimelist.net/images/anime/4/196...   Finished Airing
# 1      https://cdn.myanimelist.net/images/anime/1439/...   Finished Airing
# 2      https://cdn.myanimelist.net/images/anime/1130/...   Finished Airing
# 3      https://cdn.myanimelist.net/images/anime/10/19...   Finished Airing
# 4      https://cdn.myanimelist.net/images/anime/7/215...   Finished Airing
# ...

# %%
df_filtered = df[df["title_english"] == "Genshin Impact: Song of the night star"]
df_filtered
# Out:
#                                   title  \
# 29152  Yuanshen: Song of the night star
#
#                                 title_english  \
# 29152  Genshin Impact: Song of the night star
#
#                              title_japanese  \
# 29152  ã€åŽŸç¥žã€‘ãƒŠã‚¤ãƒˆã‚¹ã‚¿ãƒ¼ã®æ­Œ
#
#                                                    image  \
# 29152  https://cdn.myanimelist.net/img/sp/icon/apple-...
#
#                       aired_from aired_to  \
# 29152  2025-07-22 00:00:00+00:00      NaN
#
#                                                 synopsis           status  \
# 29152  Promotional video showcasing the Nod Krai cast...  Finished Airing
#
#        episodes                     rating  rank  popularity  members  \
# 29152         1  PG-13 - Teens 13 or older   0.0           0        0
#
#        favorites  score  scored_by              genres  themes demographics
# 29152          0    NaN        NaN  Adventure, Fantasy  Isekai          NaN

# %%
df_filtered = df[df["genres"].str.contains("fantasy", case=False, na=False)]
df_filtered
# Out:
#                                                    title  \
# 4                                         Bouken Ou Beet
# 10                                                Naruto
# 11                                             One Piece
# 17                                         Trinity Blood
# 23                                  Kenpuu Denki Berserk
# ...                                                  ...
# 29130  Mujikaku Seijo wa Kyou mo Muishiki ni Chikara ...
# 29131  Ore wa Subete wo "Parry" suru: Gyaku Kanchigai...
# 29142                                   Zaixia "Yingtai"
# 29150                                             Wanted
# 29152                   Yuanshen: Song of the night star
#
#                                 title_english  \
# 4                      Beet the Vandel Buster
# 10                                     Naruto
# 11                                  One Piece
# 17                              Trinity Blood
# ...

# %%
df_filtered = df[
    df["genres"].str.contains("fantasy", case=False, na=False)
    & df["title_english"].notna() & ["score"] <= 8.75
]
df_filtered
# Out:
# /tmp/ipython-input-2244814700.py:2: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   df["genres"].str.contains("fantasy", case=False, na=False)
#                                   title  \
# 0                          Cowboy Bebop
# 1       Cowboy Bebop: Tengoku no Tobira
# 2                                Trigun
# 3                    Witch Hunter Robin
# 4                        Bouken Ou Beet
# ...                                 ...
# 29148        Ibitte Konai Gibo to Gishi
# 29149               DJ Pikachu Full Set
# 29150                            Wanted
# 29151  Kanojo ga Separate o Matou Riyuu
# 29152  Yuanshen: Song of the night star
#
#                                            title_english  \
# 0                                           Cowboy Bebop
# ...

# %%
df_filtered=df[(df["popularity"]== 28656) & (df["genres"]=="comady")]
df_filtered
print(df["popularity"].unique()[:20])
# Out:
# [  42  643  261 1958 5680 1366  945 4699 1284  121    9   17 1352 8839
#   771 1697  967 1353 2237 4833]

# %%
df_filtered = df[(df["popularity"] <= 28656) & (df["episodes"] > 52)]
print(df_filtered)
# Out:
#                                                  title         title_english  \
# 5                                         Eyeshield 21                   NaN
# 9                                              Monster               Monster
# 10                                              Naruto                Naruto
# 12                                  Tennis no Oujisama  The Prince of Tennis
# 18                                    Yakitate!! Japan      Yakitate!! Japan
# ...                                                ...                   ...
# 28266                                         Nai Long                   NaN
# 28354                                  Yi Na He Qiaqia                   NaN
# 28360                               Wo Fu Kuaile Yijia                   NaN
# 28841                       Yi Na He Qiaqia 2nd Season                   NaN
# 29041  Xi Yangyang Yu Hui Tailang: Kuang Ye Xin Yuzhou                   NaN
#
# ...

# %%
total_episodes = df_filtered["episodes"].sum()
print("Total Episodes:", total_episodes)
# Out:
# Total Episodes: 154973

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='title_english',y='popularity',data=df)
# Out:
# <Axes: xlabel='title_english', ylabel='popularity'>
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 141 (\x8d) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 157 (\x9d) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 143 (\x8f) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 141 (\x8d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 157 (\x9d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df1=df["title_english"] = df["title_english"].str.encode("ascii", "ignore").str.decode("ascii")
df1
# Out:
# 0                                             Cowboy Bebop
# 1                                  Cowboy Bebop: The Movie
# 2                                                   Trigun
# 3                                       Witch Hunter Robin
# 4                                   Beet the Vandel Buster
#                                ...
# 29148    My Mother-in-Law and Sister-in-Law Who Don't B...
# 29149                                                  NaN
# 29150                                                  NaN
# 29151                                                  NaN
# 29152               Genshin Impact: Song of the night star
# Name: title_english, Length: 29153, dtype: object

# %%
df1=df["title_japanese"] = df["title_japanese"].str.encode("ascii", "ignore").str.decode("ascii")
df1
# Out:
# 0
# 1
# 2
# 3        Witch Hunter ROBIN ()
# 4
#                  ...
# 29148
# 29149                      NaN
# 29150                   WANTED
# 29151
# 29152
# Name: title_japanese, Length: 29153, dtype: object

# %%
sns.barplot(x='title_english',y='popularity',data=df)
# Out:
# <Axes: xlabel='title_english', ylabel='popularity'>

# %%
sns.scatterplot(x="popularity", y="score", data=df)
# Out:
# <Axes: xlabel='popularity', ylabel='score'>

# %%
sns.regplot(x="popularity", y="score", data=df, scatter_kws={"alpha":0.5})
plt.title("Regression: Popularity vs Score")
plt.show()

# %%
sns.barplot(x='genres',y='popularity',data=df)
# Out:
# <Axes: xlabel='genres', ylabel='popularity'>

# %%
sns.barplot(x='title_japanese',y='popularity',data=df)
df.title
# Out:
# <Axes: xlabel='title_japanese', ylabel='popularity'>
